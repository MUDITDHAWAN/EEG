# %%
n_channels = 32 
n_features = 5

# %%
import tensorflow as tf

from tensorflow.keras.layers import Conv2D, MaxPooling2D, concatenate, BatchNormalization, GlobalMaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D, Activation, Dropout, AveragePooling2D, Dense, Input
from tensorflow.keras.models import Model
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
def name_or_none(prefix, name):
    return prefix + name if (prefix is not None and name is not None) else None

# %%
def __conv_block(ip, nb_filter, dropout_rate=False, weight_decay=1e-4, block_prefix=None):
    with tf.name_scope('ConvBlock'):
        concat_axis = 1 if K.image_data_format() == 'channels_first' else -1
        
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5,
                              name=name_or_none(block_prefix, '_bn'))(ip)
        
        x = Activation('relu')(x)
        
        x = Conv2D(nb_filter, (3,1), kernel_initializer='he_normal', padding='same',
                  use_bias=False, name=name_or_none(block_prefix, '_conv2D'))(x)
        
        if(dropout_rate):
            x = Dropout(dropout_rate)(x)
        
    return x

# %%
def __dense_block(x, nb_layers, nb_filter, growth_rate, dropout_rate, weight_decay, grow_nb_filters=True,
                 block_prefix=None):
    with tf.name_scope('DenseBlock'):
        concat_axis = 1 if K.image_data_format() == 'channels_first' else -1
        
        x_list = [x]
        
        for i in range(nb_layers):
            conv_block = __conv_block(x, growth_rate, dropout_rate, weight_decay,
                                     block_prefix = name_or_none(block_prefix, '_%i' % i))
            
            x_list.append(conv_block)
            
            x = concatenate([x, conv_block], axis = concat_axis)
            
            if grow_nb_filters:
                nb_filter += growth_rate
            
            
        return x, nb_filter

# %%
def __transition_block(ip, nb_filter, compression=1.0, weight_decay=1e-4,
                       block_prefix=None, transition_pooling='max'):
    with tf.name_scope('Transition'):
        concat_axis = 1 if K.image_data_format() == 'channels_first' else -1
        
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5,
                               name=name_or_none(block_prefix, '_bn'))(ip)
        
        x = Activation('relu')(x)
        
        x = Conv2D(int(nb_filter * compression), (1,1), kernel_initializer='he_normal', padding='same',
                  use_bias=False, kernel_regularizer=l2(weight_decay), 
                  name=name_or_none(block_prefix,'_conv2D'))(x)
        
        if transition_pooling == 'avg':
            x = AveragePooling2D((2, 1), strides=(2, 2))(x)
        elif transition_pooling == 'max':
            x = MaxPooling2D((2, 1), strides=(2, 2))(x)
        
        return x

# %%
def __create_dense_net(nb_classes, img_input, depth=40, nb_dense_block=3,
                      growth_rate=12, nb_filter=-1, nb_layers_per_block=-1,
                      reduction=0.0, dropout_rate=None, weight_decay=1e-4, 
                      pooling=None, activation='softmax', transition_pooling='avg'):
    
    with tf.name_scope('Densenet'):
        concat_axis = 1 if K.image_data_format() == 'channels_first' else -1
        
        nb_layers = list(nb_layers_per_block)
        if len(nb_layers) != nb_dense_block:
            raise ValueError('If `nb_dense_block` is a list, its length must match '
                                 'the number of layers provided by `nb_layers`.')
        
        final_nb_layer = nb_layers[-1]
        nb_layers  = nb_layers[:-1]
            
        compression = 1.0 - reduction 
        
        initial_kernel = (1, 5)
        initial_strides = (1, 1)
        
        x = Conv2D(nb_filter, initial_kernel, kernel_initializer='he_normal',
                   padding='valid', name='initial_conv2D', strides=initial_strides,
                   use_bias=False, kernel_regularizer=l2(weight_decay))(img_input)
        
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5,
                                   name='initial_bn')(x)
        x = Activation('relu')(x)
        
        for block_idx in range(nb_dense_block - 1):
            # Add dense blocks
            x, nb_filter = __dense_block(x, nb_layers[block_idx], nb_filter, 
                                         growth_rate, dropout_rate=dropout_rate, 
                                        weight_decay=weight_decay, 
                                        block_prefix='dense_%i' % block_idx)
            
            # Add trainsition block
            x = __transition_block(x, nb_filter, compression=compression,
                                   weight_decay=weight_decay,
                                   block_prefix='tr_%i' % block_idx)
            
            nb_filter = int(nb_filter * compression)
        
        # The last dense_block does not have a transition_block
        x, nb_filter = __dense_block(x, final_nb_layer, nb_filter, 
                                        growth_rate, dropout_rate=dropout_rate, 
                                        weight_decay=weight_decay, 
                                        block_prefix='dense_%i' % (nb_dense_block - 1))
        
        
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x) 
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)
            
        x = Dense(nb_classes, activation=activation)(x)

        return x

# %%
def DenseNet(input_shape=None,
             depth=40,
             nb_dense_block=3,
             growth_rate=12,
             nb_filter=-1,
             nb_layers_per_block=-1,
             reduction=0.0,
             dropout_rate=0.0,
             weight_decay=1e-4,
             weights=None,
             input_tensor=None,
             pooling=None,
             classes=10,
             activation='softmax',
             transition_pooling='avg'):
    
    img_input = Input(shape=input_shape)
    
    x = __create_dense_net(classes, img_input, depth, nb_dense_block,
                           growth_rate, nb_filter, nb_layers_per_block,
                           reduction, dropout_rate, weight_decay,
                           pooling, activation, transition_pooling)
    
    # Create model.
    model = Model(img_input, x, name='densenet')
    
    return model

# %%
import tensorflow.keras.backend as K

# %%
K.set_image_data_format("channels_last")

# %%
K.image_data_format()
# Out:
# 'channels_last'

# %%
m = DenseNet(input_shape=(n_channels, n_features,1),
             depth=40,
             nb_dense_block=3,
             growth_rate=12,
             nb_filter=24,
             nb_layers_per_block=[6,6,6],
             reduction=0.0,
             dropout_rate=0.0,
             weight_decay=1e-4,
             weights=None,
             input_tensor=None,
             pooling='avg',
             classes=10,
             activation='softmax',
             transition_pooling='avg')

# %%
m.summary()
# Out:
# Model: "densenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 32, 5, 1)]   0
# __________________________________________________________________________________________________
# initial_conv2D (Conv2D)         (None, 32, 1, 24)    120         input_20[0][0]
# __________________________________________________________________________________________________
# initial_bn (BatchNormalization) (None, 32, 1, 24)    96          initial_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 1, 24)    0           initial_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_0_bn (BatchNormalizatio (None, 32, 1, 24)    96          activation_61[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 1, 24)    0           dense_0_0_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_0_conv2D (Conv2D)       (None, 32, 1, 12)    864         activation_62[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 32, 1, 36)    0           activation_61[0][0]
#                                                                  dense_0_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_1_bn (BatchNormalizatio (None, 32, 1, 36)    144         concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 1, 36)    0           dense_0_1_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_1_conv2D (Conv2D)       (None, 32, 1, 12)    1296        activation_63[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 32, 1, 48)    0           concatenate_32[0][0]
#                                                                  dense_0_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_2_bn (BatchNormalizatio (None, 32, 1, 48)    192         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 1, 48)    0           dense_0_2_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_2_conv2D (Conv2D)       (None, 32, 1, 12)    1728        activation_64[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 32, 1, 60)    0           concatenate_33[0][0]
#                                                                  dense_0_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_3_bn (BatchNormalizatio (None, 32, 1, 60)    240         concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 1, 60)    0           dense_0_3_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_3_conv2D (Conv2D)       (None, 32, 1, 12)    2160        activation_65[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 32, 1, 72)    0           concatenate_34[0][0]
#                                                                  dense_0_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_4_bn (BatchNormalizatio (None, 32, 1, 72)    288         concatenate_35[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 32, 1, 72)    0           dense_0_4_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_4_conv2D (Conv2D)       (None, 32, 1, 12)    2592        activation_66[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 32, 1, 84)    0           concatenate_35[0][0]
#                                                                  dense_0_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_5_bn (BatchNormalizatio (None, 32, 1, 84)    336         concatenate_36[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 1, 84)    0           dense_0_5_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_5_conv2D (Conv2D)       (None, 32, 1, 12)    3024        activation_67[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 32, 1, 96)    0           concatenate_36[0][0]
#                                                                  dense_0_5_conv2D[0][0]
# __________________________________________________________________________________________________
# tr_0_bn (BatchNormalization)    (None, 32, 1, 96)    384         concatenate_37[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 1, 96)    0           tr_0_bn[0][0]
# __________________________________________________________________________________________________
# tr_0_conv2D (Conv2D)            (None, 32, 1, 96)    9216        activation_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 1, 96)    0           tr_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_0_bn (BatchNormalizatio (None, 16, 1, 96)    384         max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 1, 96)    0           dense_1_0_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_0_conv2D (Conv2D)       (None, 16, 1, 12)    3456        activation_69[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 16, 1, 108)   0           max_pooling2d_9[0][0]
#                                                                  dense_1_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_1_bn (BatchNormalizatio (None, 16, 1, 108)   432         concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 1, 108)   0           dense_1_1_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_1_conv2D (Conv2D)       (None, 16, 1, 12)    3888        activation_70[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 16, 1, 120)   0           concatenate_38[0][0]
#                                                                  dense_1_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_2_bn (BatchNormalizatio (None, 16, 1, 120)   480         concatenate_39[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 16, 1, 120)   0           dense_1_2_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_2_conv2D (Conv2D)       (None, 16, 1, 12)    4320        activation_71[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 16, 1, 132)   0           concatenate_39[0][0]
#                                                                  dense_1_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_3_bn (BatchNormalizatio (None, 16, 1, 132)   528         concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 16, 1, 132)   0           dense_1_3_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_3_conv2D (Conv2D)       (None, 16, 1, 12)    4752        activation_72[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 16, 1, 144)   0           concatenate_40[0][0]
#                                                                  dense_1_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_4_bn (BatchNormalizatio (None, 16, 1, 144)   576         concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 16, 1, 144)   0           dense_1_4_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_4_conv2D (Conv2D)       (None, 16, 1, 12)    5184        activation_73[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 16, 1, 156)   0           concatenate_41[0][0]
#                                                                  dense_1_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_5_bn (BatchNormalizatio (None, 16, 1, 156)   624         concatenate_42[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 1, 156)   0           dense_1_5_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_5_conv2D (Conv2D)       (None, 16, 1, 12)    5616        activation_74[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 16, 1, 168)   0           concatenate_42[0][0]
#                                                                  dense_1_5_conv2D[0][0]
# __________________________________________________________________________________________________
# tr_1_bn (BatchNormalization)    (None, 16, 1, 168)   672         concatenate_43[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 1, 168)   0           tr_1_bn[0][0]
# __________________________________________________________________________________________________
# tr_1_conv2D (Conv2D)            (None, 16, 1, 168)   28224       activation_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 1, 168)    0           tr_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_0_bn (BatchNormalizatio (None, 8, 1, 168)    672         max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 1, 168)    0           dense_2_0_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_0_conv2D (Conv2D)       (None, 8, 1, 12)     6048        activation_76[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 8, 1, 180)    0           max_pooling2d_10[0][0]
#                                                                  dense_2_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_1_bn (BatchNormalizatio (None, 8, 1, 180)    720         concatenate_44[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 1, 180)    0           dense_2_1_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_1_conv2D (Conv2D)       (None, 8, 1, 12)     6480        activation_77[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 8, 1, 192)    0           concatenate_44[0][0]
#                                                                  dense_2_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_2_bn (BatchNormalizatio (None, 8, 1, 192)    768         concatenate_45[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 1, 192)    0           dense_2_2_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_2_conv2D (Conv2D)       (None, 8, 1, 12)     6912        activation_78[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 8, 1, 204)    0           concatenate_45[0][0]
#                                                                  dense_2_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_3_bn (BatchNormalizatio (None, 8, 1, 204)    816         concatenate_46[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 1, 204)    0           dense_2_3_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_3_conv2D (Conv2D)       (None, 8, 1, 12)     7344        activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 8, 1, 216)    0           concatenate_46[0][0]
#                                                                  dense_2_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_4_bn (BatchNormalizatio (None, 8, 1, 216)    864         concatenate_47[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 1, 216)    0           dense_2_4_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_4_conv2D (Conv2D)       (None, 8, 1, 12)     7776        activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 8, 1, 228)    0           concatenate_47[0][0]
#                                                                  dense_2_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_5_bn (BatchNormalizatio (None, 8, 1, 228)    912         concatenate_48[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 1, 228)    0           dense_2_5_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_5_conv2D (Conv2D)       (None, 8, 1, 12)     8208        activation_81[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 8, 1, 240)    0           concatenate_48[0][0]
#                                                                  dense_2_5_conv2D[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 240)          0           concatenate_49[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           2410        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 131,842
# Trainable params: 126,730
# Non-trainable params: 5,112
# __________________________________________________________________________________________________
